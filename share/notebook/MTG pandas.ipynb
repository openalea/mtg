# %%
# %matplotlib inline

# %%
from openalea.mtg.data import data_dir
import openalea.mtg
from openalea.mtg import *

# %%
g = MTG(data_dir/'noylum2.mtg')

# %%
from openalea.mtg.dataframe import *
df = to_dataframe(g)
bp = df.boxplot(column=['Az1','El1' ])

# %%
df['Inc'].hist()
# Out:
# <Axes: >

# %%
df.plot(x='XX', y='YY')
# Out:
# <Axes: xlabel='XX'>

# %%
df.plot(x='XX', y='ZZ')
# Out:
# <Axes: xlabel='XX'>

# %%
from pandas.plotting import scatter_matrix
from pandas import DataFrame
df1=DataFrame(df, columns=['scale', 'parent', 'complex', 'order'])
scatter_matrix(df1, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# array([[<Axes: xlabel='scale', ylabel='scale'>,
#         <Axes: xlabel='parent', ylabel='scale'>,
#         <Axes: xlabel='complex', ylabel='scale'>,
#         <Axes: xlabel='order', ylabel='scale'>],
#        [<Axes: xlabel='scale', ylabel='parent'>,
#         <Axes: xlabel='parent', ylabel='parent'>,
#         <Axes: xlabel='complex', ylabel='parent'>,
#         <Axes: xlabel='order', ylabel='parent'>],
#        [<Axes: xlabel='scale', ylabel='complex'>,
#         <Axes: xlabel='parent', ylabel='complex'>,
#         <Axes: xlabel='complex', ylabel='complex'>,
#         <Axes: xlabel='order', ylabel='complex'>],
#        [<Axes: xlabel='scale', ylabel='order'>,
#         <Axes: xlabel='parent', ylabel='order'>,
#         <Axes: xlabel='complex', ylabel='order'>,
#         <Axes: xlabel='order', ylabel='order'>]], dtype=object)

# %%
df1=DataFrame(df, columns=['NFe', 'Nf', 'Dist'])
scatter_matrix(df1, alpha=0.2, figsize=(6, 6), diagonal='kde')
# Out:
# array([[<Axes: xlabel='NFe', ylabel='NFe'>,
#         <Axes: xlabel='Nf', ylabel='NFe'>,
#         <Axes: xlabel='Dist', ylabel='NFe'>],
#        [<Axes: xlabel='NFe', ylabel='Nf'>,
#         <Axes: xlabel='Nf', ylabel='Nf'>,
#         <Axes: xlabel='Dist', ylabel='Nf'>],
#        [<Axes: xlabel='NFe', ylabel='Dist'>,
#         <Axes: xlabel='Nf', ylabel='Dist'>,
#         <Axes: xlabel='Dist', ylabel='Dist'>]], dtype=object)

# %%
df
# Out:
#      edge_type label  index   Dist   El1    Az1   Inc    Azm     XX     YY  \
# 5            +    S1    1.0    0.0   0.0  270.0  -8.2  320.1  -0.91 -17.95
# 6            <    S2    2.0   64.1  86.0  200.0 -80.0  255.7  -6.20 -19.00
# 8            +    S1    1.0    0.0  30.0  240.0 -15.4  104.1  -6.68 -19.92
# 9            <    S3    3.0    0.0   0.0    0.0 -80.0  255.7  -6.20 -19.00
# 11           +    S1    1.0    0.0  26.0  153.0  -3.1  185.5 -11.34  -5.37
# ...        ...   ...    ...    ...   ...    ...   ...    ...    ...    ...
# 8298         +    A1    1.0    1.3  14.0   88.0  83.9   35.6   6.61 -30.45
# 1          NaN    P1    1.0    NaN   NaN    NaN   NaN    NaN    NaN    NaN
# 2          NaN    A1    1.0   28.6 -52.0  261.0  89.0  259.6  -3.45 -21.07
# 3          NaN    S1    1.0  149.0  89.0   74.0 -88.8  271.5  -2.50 -17.68
# 0          NaN   NaN    NaN    NaN   NaN    NaN   NaN    NaN    NaN    NaN
#
#       ...  Nf  Lum1  Lum2  Lum3  Lum4   _line  parent  complex  scale  order
# 5     ... NaN   NaN   NaN   NaN   NaN    51.0     3.0      4.0      3      1
# 6     ... NaN   NaN   NaN   NaN   NaN    52.0     3.0      2.0      3      0
# 8     ... NaN   NaN   NaN   NaN   NaN    54.0     6.0      7.0      3      1
# 9     ... NaN   NaN   NaN   NaN   NaN    55.0     6.0      2.0      3      0
# 11    ... NaN   NaN   NaN   NaN   NaN    57.0     9.0     10.0      3      1
# ...   ...  ..   ...   ...   ...   ...     ...     ...      ...    ...    ...
# 8298  ... NaN   NaN   NaN   NaN   NaN  8344.0  6712.0      1.0      2      2
# 1     ... NaN   NaN   NaN   NaN   NaN    47.0     NaN      NaN      1      0
# 2     ... NaN   NaN   NaN   NaN   NaN    48.0     NaN      1.0      2      0
# 3     ... NaN   NaN   NaN   NaN   NaN    49.0     NaN      2.0      3      0
# 0     ... NaN   NaN   NaN   NaN   NaN     NaN     NaN      NaN      0      0
#
# [8304 rows x 26 columns]
